# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading Dataset

# %%
# Load the dataset
file_path = "C:/Users/TARUN/OneDrive/Desktop/My DSA/My Projects/Hotel Booking/"
df = pd.read_csv(file_path + 'hotel_bookings.csv')

# %%
data = df.copy()

# %% [markdown]
# # Exploratory Data Anlysis & Data Cleaning

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
data.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
data.shape
# Out:
# (119390, 32)

# %%
data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
data.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
data['reservation_status_date'] = pd.to_datetime(data['reservation_status_date'] , dayfirst = True, errors = 'coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
data.describe(include='object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
for col in data.describe(include='object').columns:
    print(col)
    print(data[col].unique())
    print('\n')
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
#
#
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
#
#
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
#
#
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
#  'CMR' 'BIH' 'MUS' 'COM' 'SUR' 'UGA' 'BGR' 'CIV' 'JOR' 'SYR' 'SGP' 'BDI'
#  'SAU' 'VNM' 'PLW' 'QAT' 'EGY' 'PER' 'MLT' 'MWI' 'ECU' 'MDG' 'ISL' 'UZB'
# ...

# %%
data['customer_type'].unique()
# Out:
# array(['Transient', 'Contract', 'Transient-Party', 'Group'], dtype=object)

# %%
data.drop(['company' , 'agent'] , axis = 1 , inplace = True)
data.dropna(inplace = True)

# %%
data.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483168     106.903309           0.707459
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %% [markdown]
# ### Check Outlier ###

# %%
# Selecting numerical columns
num_outlies = data.select_dtypes(include=['int64', 'float64'])
num_columns = num_outlies.shape[1]  # Total number of numerical columns

# Define subplot layout (3 in a row)
cols_per_row = 3
rows = int(np.ceil(num_columns / cols_per_row))  # Calculate required rows

# Create subplots
fig, axes = plt.subplots(rows, cols_per_row, figsize=(18, rows * 5))  

# Flatten the axes array for easy iteration
axes = axes.flatten()  

# Loop through each numerical column and create a boxplot
for i, col in enumerate(num_outlies.columns):
    axes[i].boxplot(num_outlies[col])  
    axes[i].set_title(f'Boxplot of {col}', fontsize=12)  
    axes[i].set_ylabel('Values')  
    axes[i].grid(True)

# Hide any extra subplots if total columns < (rows * cols_per_row)
for j in range(i + 1, len(axes)):  
    fig.delaxes(axes[j])  

# Adjust layout to prevent overlapping
plt.tight_layout()  

# Show the plot
plt.show()

# %%
num_col = data.select_dtypes(include=['int64', 'float64']).columns

def remove_outlliers(data,col):
    for col in num_col:
        Q1 = data[col].quantile(0.25)
        Q3 = data[col].quantile(0.75)
        
        IQR = Q3-Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        data = data[(data[col] >= lower_bound) & (data[col] <= upper_bound)]
        
    return data


clean_df = remove_outlliers(data, num_col)


print("Before removing outliers: ", data.shape)
print("After removing outliers: ", clean_df.shape)
# Out:
# Before removing outliers:  (118898, 30)
# After removing outliers:  (53823, 30)

# %%
# Selecting numerical columns
numerical_columns = clean_df.select_dtypes(include=['int64', 'float64'])
num_columns = numerical_columns.shape[1]  # Total number of numerical columns

# Define subplot layout (3 in a row)
cols_per_row = 3
rows = int(np.ceil(num_columns / cols_per_row))  # Calculate required rows

# Create subplots
fig, axes = plt.subplots(rows, cols_per_row, figsize=(18, rows * 5))  

# Flatten the axes array for easy iteration
axes = axes.flatten()  

# Loop through each numerical column and create a boxplot
for i, col in enumerate(numerical_columns.columns):
    axes[i].boxplot(numerical_columns[col])  
    axes[i].set_title(f'Boxplot of {col}', fontsize=12)  
    axes[i].set_ylabel('Values')  
    axes[i].grid(True)

# Hide any extra subplots if total columns < (rows * cols_per_row)
for j in range(i + 1, len(axes)):  
    fig.delaxes(axes[j])  

# Adjust layout to prevent overlapping
plt.tight_layout()  

# Show the plot
plt.show()

# %% [markdown]
# # Anlaysis & Visualization

# %%
cancelled_perc = clean_df['is_canceled'].value_counts(normalize = True)
print(cancelled_perc)
# Out:
# is_canceled
# 0    0.602995
# 1    0.397005
# Name: proportion, dtype: float64

# %%
plt.figure(figsize = (4,4))
plt.title('Reservation Status Count')
plt.bar(['Not Canceled' , 'Canceled'] , clean_df['is_canceled'].value_counts() , color = ['green' , 'red'] , width = 0.7)
plt.tight_layout()
plt.show()

# %%
hotel_canceled = clean_df.groupby('hotel')['is_canceled'].value_counts()
print(hotel_canceled)
# Out:
# hotel         is_canceled
# City Hotel    0              22291
#               1              15953
# Resort Hotel  0              10164
#               1               5415
# Name: count, dtype: int64

# %%
plt.figure(figsize = (8,4))
ax = sns.countplot(x='hotel', hue='is_canceled', data=clean_df, palette='Reds')
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
ax.legend(labels=['Not Canceled', 'Canceled'], bbox_to_anchor=(1,1))
plt.title('Reservation Status in Different Hotels', size=20)
plt.xlabel('Hotel')
plt.ylabel('No. of Reservation')
plt.show()

# %%
resort_hotel = clean_df[clean_df['hotel'] == 'Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize = True)
# Out:
# is_canceled
# 0    0.652417
# 1    0.347583
# Name: proportion, dtype: float64

# %%
city_hotel = clean_df[clean_df['hotel'] == 'City Hotel']
city_hotel['is_canceled'].value_counts(normalize = True)
# Out:
# is_canceled
# 0    0.582863
# 1    0.417137
# Name: proportion, dtype: float64

# %%
resort_hotel = resort_hotel.groupby('reservation_status_date')['adr'].mean()
city_hotel = city_hotel.groupby('reservation_status_date')['adr'].mean()

# %%
plt.figure(figsize = (20,9))
plt.plot(resort_hotel.index , resort_hotel , label = 'Resort Hotel')
plt.plot(city_hotel.index , city_hotel , label = 'City Hotel')
plt.title("ADR per Date", size = 20)
plt.legend()
plt.xlabel('Reservation Status Date')
plt.ylabel('ADR')
plt.show()

# %%
clean_df['month'] =clean_df['reservation_status_date'].dt.month
plt.figure(figsize = (16,8))
ax = sns.countplot(x = 'month' , hue = 'is_canceled' , data =clean_df , palette = 'bright')
ax.legend(labels= ['Not Canceled' , 'Canceled'] , bbox_to_anchor = (1,1))
plt.title('Reservation Status Per Months' , size = 20)
plt.xlabel('Month')
plt.ylabel('No. of Reservation')
plt.show()

# %%
plt.figure(figsize = (16,8))
sns.barplot( x= 'month' , y = 'adr', data = clean_df[clean_df['is_canceled'] == 1].groupby('month')['adr'].sum().reset_index())
plt.title('ADR Per Months' , size = 20)
plt.xlabel('Month') 
plt.ylabel('ARD ($)')
plt.show()

# %%
cancelled_data = clean_df[clean_df['is_canceled'] == 1]
top_10_countries = cancelled_data['country'].value_counts().sort_values(ascending = False).head(10)

# Plot the top 10 countries in pie chart
plt.figure(figsize = (8,8))
plt.pie(top_10_countries, labels = top_10_countries.index, autopct='%1.1f%%')
plt.title('Top 10 Countries with Most Canceled Reservations')
plt.show()

# %%
clean_df['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        28826
# Offline TA/TO    11770
# Groups            8431
# Direct            4180
# Corporate          604
# Complementary       11
# Aviation             1
# Name: count, dtype: int64

# %%
clean_df['market_segment'].value_counts(normalize = True)
# Out:
# market_segment
# Online TA        0.535570
# Offline TA/TO    0.218680
# Groups           0.156643
# Direct           0.077662
# Corporate        0.011222
# Complementary    0.000204
# Aviation         0.000019
# Name: proportion, dtype: float64

# %%
Market_Segment = cancelled_data['market_segment'].value_counts(normalize = True)
Market_Segment
# Out:
# market_segment
# Online TA        0.535708
# Groups           0.253136
# Offline TA/TO    0.166089
# Direct           0.036456
# Corporate        0.008564
# Complementary    0.000047
# Name: proportion, dtype: float64

# %%
# Plot the top 10 countries in pie chart
plt.figure(figsize = (6,6))
plt.pie(Market_Segment, labels = Market_Segment.index, autopct='%1.1f%%')
plt.title('Market_Segment with Canceled Reservations')
plt.show()

# %%
canceled_df_adr = cancelled_data.groupby('reservation_status_date')['adr'].mean().reset_index()
canceled_df_adr.sort_index()
canceled_df_adr.sort_values('reservation_status_date' , inplace = True)


non_cancelled_data = clean_df[clean_df['is_canceled'] == 0]
non_canceled_df_adr = non_cancelled_data.groupby('reservation_status_date')['adr'].mean().reset_index()
non_canceled_df_adr.sort_index()
non_canceled_df_adr.sort_values('reservation_status_date' , inplace = True)


plt.figure(figsize = (20,9))
plt.plot(canceled_df_adr['reservation_status_date'] , canceled_df_adr['adr'] , label = 'Canceled' , color = 'red')
plt.plot(non_canceled_df_adr['reservation_status_date'] , non_canceled_df_adr['adr'] , label = 'Non-Canceled' , color = 'green')
plt.title('ADR Per Reservation Status Date ' , size = 20)
plt.legend()
plt.xlabel('Reservation Status Date')
plt.ylabel('ADR')
plt.show()

# %% [markdown]
# **Cheking ADR (Average Daily Rate) 2016-2017**

# %%
canceled_df_adr = canceled_df_adr[(canceled_df_adr['reservation_status_date'] > '2016') & (canceled_df_adr['reservation_status_date'] < '2018')]
non_canceled_df_adr = non_canceled_df_adr[(non_canceled_df_adr['reservation_status_date'] > '2016') & (non_canceled_df_adr['reservation_status_date'] < '2018')]

plt.figure(figsize = (20,9))
plt.plot(canceled_df_adr['reservation_status_date'] , canceled_df_adr['adr'] , label = 'Canceled' , color = 'red')
plt.plot(non_canceled_df_adr['reservation_status_date'] , non_canceled_df_adr['adr'] , label = 'Non-Canceled' , color = 'green')
plt.title('ADR Per Reservation Status Date (2016-2017)' , size = 20)
plt.legend()
plt.xlabel('Reservation Status Date')
plt.ylabel('ADR')
plt.show()

# %%
Customer_type = clean_df.groupby(['customer_type', 'is_canceled']).size().unstack()

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Pie chart for Resort Hotel
resort_data = clean_df[(clean_df['hotel'] == 'Resort Hotel') & (clean_df['is_canceled'] == 1)]
resort_counts = resort_data['customer_type'].value_counts()
axes[0].pie(resort_counts, labels=resort_counts.index, autopct='%1.1f%%', startangle=90, labeldistance=1.1, pctdistance=0.8)
axes[0].set_title('Cancelled Bookings by Customer Type (Resort Hotel)')

# Pie chart for City Hotel
city_data = clean_df[(clean_df['hotel'] == 'City Hotel') & (clean_df['is_canceled'] == 1)]
city_counts = city_data['customer_type'].value_counts()
axes[1].pie(city_counts, labels=city_counts.index, autopct='%1.1f%%', startangle=90, labeldistance=1.1, pctdistance=0.8)
axes[1].set_title('Cancelled Bookings by Customer Type (City Hotel)')

plt.legend(['Not Cancelled', 'Cancelled'])
plt.tight_layout()
plt.show()

# %%
Deposit_type = clean_df.groupby(['deposit_type', 'is_canceled']).size().unstack()

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Pie chart for Resort Hotel
resort_data = clean_df[(clean_df['hotel'] == 'Resort Hotel') & (clean_df['is_canceled'] == 1)]
resort_counts = resort_data['deposit_type'].value_counts()
axes[0].pie(resort_counts, labels=resort_counts.index, autopct='%1.1f%%', startangle=90, labeldistance=1.1, pctdistance=0.8)
axes[0].set_title('Cancelled Bookings by Deposit_type (Resort Hotel)')

# Pie chart for City Hotel
city_data = clean_df[(clean_df['hotel'] == 'City Hotel') & (clean_df['is_canceled'] == 1)]
city_counts = city_data['deposit_type'].value_counts()
axes[1].pie(city_counts, labels=city_counts.index, autopct='%1.1f%%', startangle=90, labeldistance=1.1, pctdistance=0.8)
axes[1].set_title('Cancelled Bookings by Deposit_type (City Hotel)')

plt.legend(['No Deposit', 'Non Refund', 'Refundable'], loc='center', bbox_to_anchor=(0,1.15))
plt.tight_layout()
plt.show()

# %%
clean_df['total_nights'] = clean_df['stays_in_weekend_nights'] + clean_df['stays_in_week_nights']
clean_df['total_nights'].describe()
# Out:
# count    53823.000000
# mean         3.328949
# std          1.815989
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max         10.000000
# Name: total_nights, dtype: float64

# %%
lead_time_cancellation = clean_df.groupby('is_canceled')['lead_time'].mean().reset_index()

lead_time_cancellation


plt.figure(figsize=(4, 5))
sns.barplot(x='is_canceled', y='lead_time', data=lead_time_cancellation, palette='Set2')
plt.title('Average Lead Time for \n Canceled vs Non-Canceled Reservations')
plt.xlabel('Reservation Status')
plt.ylabel('Average Lead Time (days)')
plt.xticks(ticks=[0, 1], labels=['Not Canceled', 'Canceled'])

plt.tight_layout()
plt.show()
